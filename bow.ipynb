# %%
from wordcloud import WordCloud
import matplotlib.pyplot as mat
import nltk
import os
import re
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Télechargement des librairies NLTK

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("punkt_tab")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/lydie_15-03/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/lydie_15-03/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/lydie_15-03/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/lydie_15-03/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/lydie_15-03/nltk_data...
# True

# %% [markdown]
# ### Fonction de traitement des dse mots

# %%
def bow(files):
    
    tokens = word_tokenize(files.lower())
    filte = [token for token in tokens if token not in stopwords.words('english') and token.isalpha()]

    lemmatiser = WordNetLemmatizer()

    lemmitazer = [lemmatiser.lemmatize(token) for token in filte]
    processed = Counter(lemmitazer)
    word_freq_df = pd.DataFrame(processed.items(), columns=['Word', 'Frequency'])
    frequency = word_freq_df.sort_values(by='Frequency', ascending=False)
    
    return frequency

# %% [markdown]
# ### Boucle d'affichage des Bow

# %%
for i in os.listdir("Text/"):
    with open(f'Text/{i}', 'r', encoding='utf-8') as file:
        files = file.read()
        name = i.replace('.txt', '')
        l = bow(files)
        display(name)
        display(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 for i in os.listdir("Text/"):
#       2     with open(f'Text/{i}', 'r', encoding='utf-8') as file:
#       3         files = file.read()
#       4         name = i.replace('.txt', '')
# ----> 5         l = bow(files)
#       6         display(name)
#       7         display(l)
#       8
#
# Cell In[3], line 9, in bow(files)
#       5
#       6     lemmatiser = WordNetLemmatizer()
#       7
#       8     lemmitazer = [lemmatiser.lemmatize(token) for token in filte]
# ----> 9     processed = Counter(lemmitazer)
#      10     word_freq_df = pd.DataFrame(processed.items(), columns=['Word', 'Frequency'])
#      11     frequency = word_freq_df.sort_values(by='Frequency', ascending=False)
#      12
#
# NameError: name 'Counter' is not defined
